# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
data = pd.read_csv('Loan Default Data.csv')

# %%
data.head(5)
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  \
# 0               45                1441      01-01-84        Salaried
# 1               45                1502      31-07-85   Self employed
# 2               45                1497      24-08-85   Self employed
# 3               45                1501      30-12-93   Self employed
# 4               45                1495      09-12-77   Self employed
#
#        ...      SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  \
# ...

# %%
data.isnull().sum()
# Out:
# UniqueID                                  0
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# ...

# %%
data['Employment.Type'].value_counts()
# Out:
# Self employed    127635
# Salaried          97858
# Name: Employment.Type, dtype: int64

# %%
data.fillna(method = 'backfill',inplace=True)

# %%
data.isnull().sum()
# Out:
# UniqueID                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# Date.of.Birth                          0
# Employment.Type                        0
# DisbursalDate                          0
# State_ID                               0
# Employee_code_ID                       0
# MobileNo_Avl_Flag                      0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# PRI.ACTIVE.ACCTS                       0
# ...

# %%
data['Employment.Type'].value_counts()
# Out:
# Self employed    132002
# Salaried         101152
# Name: Employment.Type, dtype: int64

# %%
data.head(3)
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  \
# 0               45                1441      01-01-84        Salaried
# 1               45                1502      31-07-85   Self employed
# 2               45                1497      24-08-85   Self employed
#
#        ...      SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  \
# 0      ...                          0                     0
# 1      ...                          0                     0
# 2      ...                          0                     0
#
#    PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# 0                   0               0                             0
# ...

# %%
dates = data.iloc[:,8]
dates
# Out:
# 0         01-01-84
# 1         31-07-85
# 2         24-08-85
# 3         30-12-93
# 4         09-12-77
# 5         08-09-90
# 6         01-06-88
# 7         04-10-89
# 8         15-11-91
# 9         01-06-68
# 10        01-01-79
# 11        07-09-84
# 12        01-06-74
# 13        16-08-84
# 14        18-02-73
# 15        05-07-94
# 16        01-06-76
# 17        27-02-83
# 18        10-08-88
# 19        16-04-80
# 20        01-11-78
# 21        29-02-84
# 22        14-07-94
# 23        31-05-79
# 24        02-01-89
# 25        01-01-86
# 26        02-08-68
# 27        01-01-76
# 28        12-09-72
# 29        27-06-69
#             ...
# 233124    30-09-84
# 233125    13-05-88
# 233126    02-12-74
# 233127    05-03-76
# 233128    06-04-69
# 233129    18-07-80
# 233130    16-01-64
# 233131    31-12-94
# 233132    03-09-92
# 233133    31-12-80
# 233134    01-06-81
# 233135    01-01-96
# 233136    02-11-72
# 233137    14-09-73
# 233138    20-03-83
# 233139    14-08-81
# ...

# %%
Date = []
for i in dates: 
    Date.append(datetime.strptime(i, '%d-%m-%y'))
Date
# Out:
# [datetime.datetime(1984, 1, 1, 0, 0),
#  datetime.datetime(1985, 7, 31, 0, 0),
#  datetime.datetime(1985, 8, 24, 0, 0),
#  datetime.datetime(1993, 12, 30, 0, 0),
#  datetime.datetime(1977, 12, 9, 0, 0),
#  datetime.datetime(1990, 9, 8, 0, 0),
#  datetime.datetime(1988, 6, 1, 0, 0),
#  datetime.datetime(1989, 10, 4, 0, 0),
#  datetime.datetime(1991, 11, 15, 0, 0),
#  datetime.datetime(2068, 6, 1, 0, 0),
#  datetime.datetime(1979, 1, 1, 0, 0),
#  datetime.datetime(1984, 9, 7, 0, 0),
#  datetime.datetime(1974, 6, 1, 0, 0),
#  datetime.datetime(1984, 8, 16, 0, 0),
#  datetime.datetime(1973, 2, 18, 0, 0),
#  datetime.datetime(1994, 7, 5, 0, 0),
#  datetime.datetime(1976, 6, 1, 0, 0),
#  datetime.datetime(1983, 2, 27, 0, 0),
#  datetime.datetime(1988, 8, 10, 0, 0),
#  datetime.datetime(1980, 4, 16, 0, 0),
#  datetime.datetime(1978, 11, 1, 0, 0),
#  datetime.datetime(1984, 2, 29, 0, 0),
#  datetime.datetime(1994, 7, 14, 0, 0),
#  datetime.datetime(1979, 5, 31, 0, 0),
# ...

# %%
data = data.drop('Date.of.Birth',axis = 1)

# %%
data['Date.of.Birth'] = Date

# %%
dates = data.loc[:,'DisbursalDate']
dates
# Out:
# 0         03-08-18
# 1         26-09-18
# 2         01-08-18
# 3         26-10-18
# 4         26-09-18
# 5         19-09-18
# 6         23-09-18
# 7         16-09-18
# 8         05-09-18
# 9         16-09-18
# 10        29-09-18
# 11        03-09-18
# 12        30-08-18
# 13        30-08-18
# 14        31-08-18
# 15        22-10-18
# 16        18-09-18
# 17        20-09-18
# 18        06-09-18
# 19        11-10-18
# 20        20-10-18
# 21        27-08-18
# 22        08-10-18
# 23        17-09-18
# 24        10-09-18
# 25        18-10-18
# 26        16-08-18
# 27        10-10-18
# 28        23-10-18
# 29        19-09-18
#             ...
# 233124    17-10-18
# 233125    13-10-18
# 233126    05-10-18
# 233127    13-10-18
# 233128    23-10-18
# 233129    10-09-18
# 233130    20-08-18
# 233131    27-09-18
# 233132    30-08-18
# 233133    26-10-18
# 233134    24-10-18
# 233135    26-10-18
# 233136    23-10-18
# 233137    27-10-18
# 233138    23-10-18
# 233139    24-10-18
# ...

# %%
Date = []
for i in dates: 
    Date.append(datetime.strptime(i, '%d-%m-%y'))
Date
# Out:
# [datetime.datetime(2018, 8, 3, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2018, 8, 1, 0, 0),
#  datetime.datetime(2018, 10, 26, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2018, 9, 19, 0, 0),
#  datetime.datetime(2018, 9, 23, 0, 0),
#  datetime.datetime(2018, 9, 16, 0, 0),
#  datetime.datetime(2018, 9, 5, 0, 0),
#  datetime.datetime(2018, 9, 16, 0, 0),
#  datetime.datetime(2018, 9, 29, 0, 0),
#  datetime.datetime(2018, 9, 3, 0, 0),
#  datetime.datetime(2018, 8, 30, 0, 0),
#  datetime.datetime(2018, 8, 30, 0, 0),
#  datetime.datetime(2018, 8, 31, 0, 0),
#  datetime.datetime(2018, 10, 22, 0, 0),
#  datetime.datetime(2018, 9, 18, 0, 0),
#  datetime.datetime(2018, 9, 20, 0, 0),
#  datetime.datetime(2018, 9, 6, 0, 0),
#  datetime.datetime(2018, 10, 11, 0, 0),
#  datetime.datetime(2018, 10, 20, 0, 0),
#  datetime.datetime(2018, 8, 27, 0, 0),
#  datetime.datetime(2018, 10, 8, 0, 0),
#  datetime.datetime(2018, 9, 17, 0, 0),
# ...

# %%
data = data.drop('DisbursalDate',axis = 1)

# %%
data['DisbursalDate'] = Date

# %%
data.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Employment.Type  State_ID  \
# 0               45                1441        Salaried         6
# 1               45                1502   Self employed         6
# 2               45                1497   Self employed         6
# 3               45                1501   Self employed         6
# 4               45                1495   Self employed         6
#
#        ...        PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  \
# 0      ...                         0               0
# ...

# %%
def fun(x):
    x = x.split(' ')
    y = str(x[0])[:-3]
    y =12 * int(y)
    x = int( str(x[1])[:-3])
    x = x+y
    return x

# %%
a = ["AVERAGE.ACCT.AGE","CREDIT.HISTORY.LENGTH"]
for i in a:
    data[i] = data[i].map(lambda x: fun(x) )

# %%
data.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Employment.Type  State_ID  \
# 0               45                1441        Salaried         6
# 1               45                1502   Self employed         6
# 2               45                1497   Self employed         6
# 3               45                1501   Self employed         6
# 4               45                1495   Self employed         6
#
#        ...        PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  \
# 0      ...                         0               0
# ...

# %%
for i in data.columns:
    print(i,type(data[i][0]),sep = '----------->')
# Out:
# UniqueID-----------><class 'numpy.int64'>
# disbursed_amount-----------><class 'numpy.int64'>
# asset_cost-----------><class 'numpy.int64'>
# ltv-----------><class 'numpy.float64'>
# branch_id-----------><class 'numpy.int64'>
# supplier_id-----------><class 'numpy.int64'>
# manufacturer_id-----------><class 'numpy.int64'>
# Current_pincode_ID-----------><class 'numpy.int64'>
# Employment.Type-----------><class 'str'>
# State_ID-----------><class 'numpy.int64'>
# Employee_code_ID-----------><class 'numpy.int64'>
# MobileNo_Avl_Flag-----------><class 'numpy.int64'>
# Aadhar_flag-----------><class 'numpy.int64'>
# PAN_flag-----------><class 'numpy.int64'>
# VoterID_flag-----------><class 'numpy.int64'>
# Driving_flag-----------><class 'numpy.int64'>
# Passport_flag-----------><class 'numpy.int64'>
# PERFORM_CNS.SCORE-----------><class 'numpy.int64'>
# PERFORM_CNS.SCORE.DESCRIPTION-----------><class 'str'>
# PRI.NO.OF.ACCTS-----------><class 'numpy.int64'>
# ...

# %%
data['PERFORM_CNS.SCORE.DESCRIPTION'].value_counts()
# Out:
# No Bureau History Available                                116950
# C-Very Low Risk                                             16045
# A-Very Low Risk                                             14124
# D-Very Low Risk                                             11358
# B-Very Low Risk                                              9201
# M-Very High Risk                                             8776
# F-Low Risk                                                   8485
# K-High Risk                                                  8277
# H-Medium Risk                                                6855
# E-Low Risk                                                   5821
# I-Medium Risk                                                5557
# G-Low Risk                                                   3988
# Not Scored: Sufficient History Not Available                 3765
# J-High Risk                                                  3748
# ...

# %%
data.isnull().sum()
# Out:
# UniqueID                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# Employment.Type                        0
# State_ID                               0
# Employee_code_ID                       0
# MobileNo_Avl_Flag                      0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# PRI.ACTIVE.ACCTS                       0
# PRI.OVERDUE.ACCTS                      0
# PRI.CURRENT.BALANCE                    0
# ...

# %%
import matplotlib.pyplot as ply
from sklearn import preprocessing

# %%
for i in ['Date.of.Birth','DisbursalDate']:    
    data[i] = data[i].map(lambda x: x.toordinal())

# %%
encode = preprocessing.LabelEncoder()

# %%
for i in data.columns:
    if isinstance(data[i][0],str):
        print("One more encoded")
        data[i] = encode.fit_transform(data[i])
# Out:
# One more encoded
# One more encoded

# %%
x = data

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

x = add_constant(x)

pd.Series([variance_inflation_factor(x.values, i) 
               for i in range(x.shape[1])], 
              index=x.columns)
# Out:
# D:\Softwares\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1386: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# UniqueID                                 74.091206
# disbursed_amount                         31.665382
# asset_cost                               29.489056
# ltv                                      15.099314
# branch_id                                 1.096346
# supplier_id                               1.127655
# manufacturer_id                           1.052480
# Current_pincode_ID                        1.353107
# Employment.Type                           1.069248
# State_ID                                  1.113634
# Employee_code_ID                          1.047161
# MobileNo_Avl_Flag                         0.000000
# Aadhar_flag                               8.132093
# PAN_flag                                  1.068245
# VoterID_flag                              7.162143
# ...

# %% [markdown]
# Low Vif :
# DisbursalDate
# SEC.DISBURSED.AMOUNT
# SEC.SANCTIONED.AMOUNT
# PRI.DISBURSED.AMOUNT
# PRI.SANCTIONED.AMOUNT
# PERFORM_CNS.SCORE
# PERFORM_CNS.SCORE.DESCRIPTION
# UniqueID
# disbursed_amount
# asset_cost
# ltv
# Low Significant test:
#
# SEC.INSTAL.AMT
# SEC.CURRENT.BALANCE
# SEC.SANCTIONED.AMOUNT
# SEC.DISBURSED.AMOUNT
# PRIMARY.INSTAL.AMT
# PRI.DISBURSED.AMOUNT
# PRI.SANCTIONED.AMOUNT
# PRI.CURRENT.BALANCE
# MobileNo_Avl_Flag

# %%
import scipy.stats as stats
from scipy.stats import chi2_contingency

Significance = pd.Series()

for i in x.columns:
    dfObserved = pd.crosstab(x[i],x['loan_default'])
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    Significance[i] = p

Significance.sort_values()
# Out:
# loan_default                            0.000000e+00
# branch_id                               0.000000e+00
# supplier_id                             0.000000e+00
# Current_pincode_ID                      0.000000e+00
# PERFORM_CNS.SCORE.DESCRIPTION           0.000000e+00
# State_ID                                0.000000e+00
# Employee_code_ID                        0.000000e+00
# PERFORM_CNS.SCORE                       0.000000e+00
# DisbursalDate                          3.345849e-187
# PRI.OVERDUE.ACCTS                      3.291632e-112
# VoterID_flag                            5.603683e-99
# NO.OF_INQUIRIES                         1.117569e-95
# manufacturer_id                         1.527738e-93
# Aadhar_flag                             1.179200e-89
# PRI.ACTIVE.ACCTS                        6.539244e-73
# PRI.NO.OF.ACCTS                         3.947704e-68
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS     2.528829e-66
# disbursed_amount                        5.771384e-66
# ...

# %%
import scipy.stats as stats
for  i in x.columns:
    print(i,'-------->',stats.f_oneway(x[i],x['loan_default']))
# Out:
# UniqueID --------> F_onewayResult(statistic=14348204.23773441, pvalue=0.0)
# disbursed_amount --------> F_onewayResult(statistic=4094324.885317847, pvalue=0.0)
# asset_cost --------> F_onewayResult(statistic=3738909.024151182, pvalue=0.0)
# ltv --------> F_onewayResult(statistic=9854228.400645033, pvalue=0.0)
# branch_id --------> F_onewayResult(statistic=252800.30616978437, pvalue=0.0)
# supplier_id --------> F_onewayResult(statistic=7374285.321022451, pvalue=0.0)
# manufacturer_id --------> F_onewayResult(statistic=2251134.703820293, pvalue=0.0)
# Current_pincode_ID --------> F_onewayResult(statistic=536995.2107310194, pvalue=0.0)
# Employment.Type --------> F_onewayResult(statistic=68369.0083739453, pvalue=0.0)
# State_ID --------> F_onewayResult(statistic=571188.5177862645, pvalue=0.0)
# Employee_code_ID --------> F_onewayResult(statistic=588368.6037986369, pvalue=0.0)
# MobileNo_Avl_Flag --------> F_onewayResult(statistic=840932.7632135303, pvalue=0.0)
# ...

# %%
data = data.drop(["SEC.DISBURSED.AMOUNT" , "SEC.SANCTIONED.AMOUNT" ,"PRI.DISBURSED.AMOUNT","PRI.SANCTIONED.AMOUNT" , "UniqueID"],axis =1)

# %%
data.head()
# Out:
#    disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0             50578       58400  89.55         67        22807
# 1             47145       65550  73.23         67        22807
# 2             53278       61360  89.63         67        22807
# 3             57513       66113  88.48         67        22807
# 4             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID  Employment.Type  State_ID  \
# 0               45                1441                0         6
# 1               45                1502                1         6
# 2               45                1497                1         6
# 3               45                1501                1         6
# 4               45                1495                1         6
#
#    Employee_code_ID      ...        PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  \
# 0              1998      ...                         0               0
# ...

# %%
abc = data.copy()

# %%
data.loan_default.value_counts()
# Out:
# 0    182543
# 1     50611
# Name: loan_default, dtype: int64

# %%
dellist = data[data.loan_default == 0].sample(130000).index

# %%
data = data.drop(dellist,axis =0)

# %%
data.loan_default.value_counts()
# Out:
# 0    52543
# 1    50611
# Name: loan_default, dtype: int64

# %%
x = data.drop('loan_default',axis =1)

# %%
y = data['loan_default']

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
tr_x,ts_x,tr_y,ts_y = train_test_split(x,y,test_size=0.25)

# %%
lr.fit(tr_x,tr_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(ts_x,ts_y)*100
# Out:
# 57.415952537903756

# %%
from sklearn import ensemble
classifier = ensemble.RandomForestClassifier(criterion='entropy',
                                             random_state=3,
                                             min_samples_leaf=4,
                                             n_estimators=75,
                                             n_jobs=-1,
                                             oob_score=True)
classifier.fit(tr_x, tr_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=4, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=-1,
#             oob_score=True, random_state=3, verbose=0, warm_start=False)

# %%
classifier.score(ts_x,ts_y)*100
# Out:
# 61.27418666873473

# %% [markdown]
# import pip

# %% [markdown]
# pip.main(['install', 'h2o'])

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(ts_y,classifier.predict(ts_x))
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.6126857518723741

# %%
print(false_positive_rate, true_positive_rate, thresholds)
# Out:
# [0.         0.38450426 1.        ] [0.         0.60987576 1.        ] [2 1 0]

# %%
n_estimators = [1, 2, 4, 8, 16, 32, 64, 100, 200]
train_results = []
test_results = []
for estimator in n_estimators:
   rf = ensemble.RandomForestClassifier(n_estimators=estimator, n_jobs=-1)
   rf.fit(tr_x, tr_y)
   train_pred = rf.predict(tr_x)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(tr_y, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = rf.predict(ts_x)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(ts_y, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)

# %%
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(n_estimators, train_results, 'b', label="Train AUC")
line2, = plt.plot(n_estimators, test_results, 'r', label="Test AUC")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.xticks=[i*10 for i in range(20)]
plt.grid = True
plt.ylabel('AUC score')
plt.xlabel('n_estimators')
plt.show()
